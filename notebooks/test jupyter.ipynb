# %% [markdown]
# # CERVERA-TRONX 3000
# ---
# <em>Cervera Tronx 3000 es programa de cálculo diferecial/integral basado en el uso de una clase llamada <strong>Funcion</strong>, a la que se le han definido funciones, que son operaciones de cálculo diferencial e integral simbólico y numérico<em>
# ***

# %% [markdown]
# Comenzamos llamando a las librerías necesarias para esta clase:

# %%
import sys
sys.path.append('../src')
# Out:
# Running cells with 'env (Python 3.8.19)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\Mateo Márquez\Documents\NAAT\Cervera-Robot\env ipykernel --update-deps --force-reinstall'

# %%
# !conda install -p c:\Users\Mateo Márquez\Documents\NAAT\Cervera-Robot\env ipykernel --update-deps --force-reinstall
# Out:
# Running cells with 'env (Python 3.8.19)' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p c:\Users\Mateo Márquez\Documents\NAAT\Cervera-Robot\env ipykernel --update-deps --force-reinstall'

# %%
import Function_class as fc
import sympy as sp
import Graph_generator as gf

# %% [markdown]
# Ahora solicitamos la función a analizar y su variable independiente:

# %%
F=input('Ingrese la función a analizar (f(x) o f(x,y)): ')
x=input('Ingrese la variable de interés: ')
dimen=int(input('¿Cuántas variables independientes tiene la función?: '))
Fs=sp.sympify(F)
xs=sp.symbols(x)
Fx=fc.funcion(Fs,xs)

# %% [markdown]
# Seleccionamos el cálculo a realizar y la información necesaria para llevarlo a cabo.
# <p>Recibimos el resultado del calculo y en su caso, la gráfica de las funciones obtenidas

# %%
i=int(input('Indique el número de la operación a realizar:\n 1. Derivada simbólica\n 2. Integral simbólica\n 3. Derivada numérica\n 4. Integral numérica\n'))
if i==1:
    print(f'La derivada simbólica de {Fx.expr} es\n {Fx.sderiv()}')
    gf.grapher(x,F,dimen,str(Fx.sderiv()))
elif i==2:
    print(f'La integral simbólica de {Fx.expr} es\n {Fx.sinteg()}')
    gf.grapher(x,F,dimen,str(Fx.sinteg()))
elif i==3:
    a=float(input('Ingrese punto dónde calcular la derivada:\n'))
    h=float(input('Ingrese el incremento para la derivada numérica:\n'))
    print(f'La derivada numérica de {Fx.expr} en {a} con delta {h} es\n {Fx.nderiv(a,h)}')
    gf.grapher(x,F,dimen)
elif i==4:
    a=float(input('Ingrese punto inicial de integración:\n'))
    b=float(input('Ingrese punto final de integración:\n'))
    print(f'La integral numérica de {Fx.expr} desde {a} hasta {b} es\n {Fx.ninteg(a,b)}')
    gf.grapher(x,F,dimen)
# Out:
# La derivada simbólica de 1/(exp(-x + y) + 1) es
#  exp(-x + y)/(exp(-x + y) + 1)**2

# %% [markdown]
# El código puede reiniciarse para analizar otras funciones y operaciones
